# %% [markdown]
# ### Exercise:
# Build decision tree model to predict survival based on certain parameters
#
# In this file using following columns build a model to predict if person would survive or not,
#
#     Pclass
#     Sex
#     Age
#     Fare
#
# Calculate score of your model

# %%
import pandas as pd

# %%
titanic=pd.read_csv(r"C:\Users\evilk\Downloads\titanic.csv")
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
input=titanic[['Pclass','Age','Sex','Fare']]
input
# Out:
#      Pclass   Age     Sex     Fare
# 0         3  22.0    male   7.2500
# 1         1  38.0  female  71.2833
# 2         3  26.0  female   7.9250
# 3         1  35.0  female  53.1000
# 4         3  35.0    male   8.0500
# ..      ...   ...     ...      ...
# 886       2  27.0    male  13.0000
# 887       1  19.0  female  30.0000
# 888       3   NaN  female  23.4500
# 889       1  26.0    male  30.0000
# 890       3  32.0    male   7.7500
#
# [891 rows x 4 columns]

# %%
target=titanic['Survived']
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
import numpy as np

# %%
input.isna().sum()
# Out:
# Pclass      0
# Age       177
# Sex         0
# Fare        0
# dtype: int64

# %%
print(177+714)
# Out:
# 891

# %%
input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Age     714 non-null    float64
#  2   Sex     891 non-null    object
#  3   Fare    891 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 28.0+ KB

# %%
meanOfAge=input['Age'].mean()
input['Age']=input['Age'].fillna(meanOfAge)
meanOfAge
# Out:
# C:\Users\evilk\AppData\Local\Temp\ipykernel_19436\2336277863.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input['Age']=input['Age'].fillna(meanOfAge)
# np.float64(29.69911764705882)

# %%
input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Age     891 non-null    float64
#  2   Sex     891 non-null    object
#  3   Fare    891 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 28.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
input['Sex_n']=le.fit_transform(input['Sex'])
# Out:
# C:\Users\evilk\AppData\Local\Temp\ipykernel_19436\3013712090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input['Sex_n']=le.fit_transform(input['Sex'])

# %%
input_n=input.drop(['Sex'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(input_n,target,test_size=0.3)

# %%
x_train
# Out:
#      Pclass   Age      Fare  Sex_n
# 880       2  25.0   26.0000      0
# 419       3  10.0   24.1500      0
# 438       1  64.0  263.0000      1
# 884       3  25.0    7.0500      1
# 446       2  13.0   19.5000      0
# ..      ...   ...       ...    ...
# 551       2  27.0   26.0000      1
# 745       1  70.0   71.0000      1
# 138       3  16.0    9.2167      1
# 219       2  30.0   10.5000      1
# 373       1  22.0  135.6333      1
#
# [623 rows x 4 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
Model=DecisionTreeClassifier()

# %%
Model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pre = Model.predict(x_test)

# %%
Model.score(x_test,y_test)
# Out:
# 0.7574626865671642

# %%
Model.score(x_train,y_train)
# Out:
# 0.9807383627608347

# %%
from sklearn.metrics import accuracy_score,precision_score

accuracy=accuracy_score(y_test,y_pre)
precision=precision_score(y_test,y_pre)

print("Accuracy of model : ",accuracy)
print("Precision of model : ",precision)
# Out:
# Accuracy of model :  0.7574626865671642
# Precision of model :  0.7090909090909091
