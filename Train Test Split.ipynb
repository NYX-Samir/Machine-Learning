# %% [markdown]
# ### Training And Testing Available Data
#
# We have a dataset containing prices of used BMW cars. We are going to analyze this dataset and build a prediction function that can predict a price by taking mileage and age of the car as input. We will use sklearn train_test_split method to split training and testing dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\evilk\Downloads\archive\carprices2.csv")
df.head(10)
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500
# 5    59000         5          26750
# 6    52000         5          32000
# 7    72000         6          19300
# 8    91000         8          12000
# 9    67000         6          22000

# %%
plt.scatter(x='Mileage',y='Age(yrs)',data=df)
plt.show()

# %%
plt.scatter(x='Mileage',y='Sell Price($)',data=df)
plt.show()

# %%
X=df[['Mileage','Age(yrs)']]
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
Y=df['Sell Price($)']
Y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 17    69000         5
# 9     67000         6
# 6     52000         5
# 3     22500         2
# 16    28000         2
# 7     72000         6
# 5     59000         5
# 10    83000         7
# 14    82450         7
# 2     57000         5
# 11    79000         7
# 19    52000         5
# 4     46000         4
# 8     91000         8

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 15    25400         3
# 18    87600         8
# 13    58780         4
# 12    59000         5
# 0     69000         6
# 1     35000         3

# %%
from sklearn.linear_model import LinearRegression
le=LinearRegression()

# %%
le.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
le.predict(X_test)
# Out:
# array([40292.2032793 , 16466.6358559 , 23515.75950813, 25760.12339217,
#        22394.61095328, 34785.57621386])

# %%
le.score(X_test,Y_test)
# Out:
# 0.7988079303838125

# %%
le.score(X_train,Y_train)
# Out:
# 0.9605118943767937
